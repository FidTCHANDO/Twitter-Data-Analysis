# %% [markdown]
# ## **Objective **
# ### Social Media Tweet Exploratory Data Analysis (EDA) on Twitter Dataset

# %% [markdown]
# ## Data Understanding
# ### Loading necessary packages

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import STOPWORDS,WordCloud
from gensim import corpora
import pandas as pd
import statistics
import string
import os
import re

# %% [markdown]
# Data acquisition
#
# For this example we have two option for data acquisition:
#
# *   You can download Twitter dataset directly from Twitter
# *   By registering as a developer using this link [Here](https://developer.twitter.com/en)
#
# *   Or you can use downloaded data found at Week0/Tuesday/cleaned_fintech_data.csv

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'cleaned_fintech_data.csv', 'EDA-Twitter.ipynb']

# %%
#To read csv file and create dataframe
tweets = pd.read_csv('cleaned_fintech_data.csv')
tweets.head()
# Out:
#    Unnamed: 0                      created_at  \
# 0         0.0  Thu Jun 17 06:26:34 +0000 2021
# 1         1.0  Thu Jun 17 06:26:37 +0000 2021
# 2         2.0  Thu Jun 17 06:26:42 +0000 2021
# 3         3.0  Thu Jun 17 06:26:44 +0000 2021
# 4         4.0  Thu Jun 17 06:26:47 +0000 2021
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                        original_text  \
# 0  Giving forth life is becoming a burden in Keny...
# 1  Teenmaar - 26cr\nPanja - 32.5cr\nGabbarsingh -...
# 2  Rei chintu 2013 lo Vachina Ad Nizam ne 2018 lo...
# 3  Today is World Day to Combat #Desertification ...
# 4  Hearing #GregHunt say he's confident vaccines ...
#
#                                           clean_text  \
# 0  Giving forth life becoming burden Kenya This m...
# 1  Teenmaar crPanja crGabbarsingh cr Khaleja Kuda...
# 2  Rei chintu lo Vachina Ad Nizam ne lo kottaru f...
# 3  Today World Day Combat Restoring degraded land...
# 4  Hearing say 's confident vaccines delivered li...
#
#                                            sentiment            polarity  \
# 0  Sentiment(polarity=0.3194444444444445, subject...  0.3194444444444445
# 1          Sentiment(polarity=0.0, subjectivity=0.0)                 0.0
# 2          Sentiment(polarity=0.0, subjectivity=0.0)                 0.0
# 3        Sentiment(polarity=0.25, subjectivity=0.65)                0.25
# 4  Sentiment(polarity=0.5, subjectivity=0.8333333...                 0.5
#
#          subjectivity lang favorite_count  ... original_author screen_count  \
# 0  0.5305555555555556   en              0  ...        reen_law          398
# 1                 0.0   in              0  ...      Amigo9999_        19047
# 2                 0.0   hi              0  ...     MallaSuhaas        47341
# 3                0.65   en              0  ...     CIACOceania         7039
# 4  0.8333333333333334   en              0  ...   MccarronWendy        26064
#
#   followers_count friends_count possibly_sensitive  \
# 0              70           223                NaN
# 1             132          1084                NaN
# 2            2696          2525                NaN
# 3             343           387                NaN
# 4             419           878                NaN
#
#                                hashtags  user_mentions place  \
# 0                                   NaN  janetmachuka_   NaN
# 1                                   NaN    maheshblood   NaN
# 2                                   NaN    Hail_Kalyan   NaN
# 3  Desertification, Drought, resilience    EdwardVrkic   NaN
# 4                    GregHunt, Morrison  WriteWithDave   NaN
#
#     place_coord_boundaries                  timestamp
# 0                      NaN  2021-06-17 06:26:34+00:00
# 1                    India  2021-06-17 06:26:37+00:00
# 2                    Vizag  2021-06-17 06:26:42+00:00
# 3         Papua New Guinea  2021-06-17 06:26:44+00:00
# 4  Sydney, New South Wales  2021-06-17 06:26:47+00:00
#
# [5 rows x 21 columns]

# %%
#To get information abou the data
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5621 entries, 0 to 5620
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5620 non-null   float64
#  1   created_at              5621 non-null   object
#  2   source                  5621 non-null   object
#  3   original_text           5621 non-null   object
#  4   clean_text              5617 non-null   object
#  5   sentiment               5621 non-null   object
#  6   polarity                5621 non-null   object
#  7   subjectivity            5621 non-null   object
#  8   lang                    5621 non-null   object
#  9   favorite_count          5621 non-null   object
#  10  retweet_count           5621 non-null   object
#  11  original_author         5621 non-null   object
#  12  screen_count            5621 non-null   object
#  13  followers_count         5621 non-null   object
#  14  friends_count           5621 non-null   object
#  15  possibly_sensitive      131 non-null    object
#  16  hashtags                813 non-null    object
#  17  user_mentions           5621 non-null   object
#  18  place                   1 non-null      object
#  19  place_coord_boundaries  3603 non-null   object
#  20  timestamp               5621 non-null   object
# dtypes: float64(1), object(20)
# memory usage: 922.3+ KB

# %%
# Retweets count
tweets.retweet_count.isnull().count()
# Empty variable
# Out:
# 5621

# %%
# Followers counts
plt.figure(figsize=(4, 4), dpi=200)
plt.hist(tweets[tweets.followers_count != None].followers_count, bins = 20)
plt.title("Histogram of followers counts")
plt.show()

# %% [markdown]
# *Check if there are errors in the data*

# %%
print("The number of missing value(s): {}".format(tweets.isnull().sum().sum()))
print("Columons having columns value:{}".format(tweets.columns[tweets.isnull().any()]))
# Out:
# The number of missing value(s): 17941
# Columons having columns value:Index(['Unnamed: 0', 'clean_text', 'possibly_sensitive', 'hashtags', 'place',
#        'place_coord_boundaries'],
#       dtype='object')

# %% [markdown]
# ### Data Preparation
#
# *   Making correction
# *   Reformatting
# *   Combining Dataset

# %%
tweets_df = pd.DataFrame(columns=['text',"lang"])

tweets_df['text'] =  tweets['clean_text'].to_list()
tweets_df['lang'] = tweets['lang']

# %%
# drop row having Null value
tweets_df.dropna()
tweets_df
# Out:
#                                                    text lang
# 0     Giving forth life becoming burden Kenya This m...   en
# 1     Teenmaar crPanja crGabbarsingh cr Khaleja Kuda...   in
# 2     Rei chintu lo Vachina Ad Nizam ne lo kottaru f...   hi
# 3     Today World Day Combat Restoring degraded land...   en
# 4     Hearing say 's confident vaccines delivered li...   en
# ...                                                 ...  ...
# 5616  Lambie voted AGAINST Medivac Carbon tax protec...   en
# 5617  Idhi bathuku Most Day1 Records In Nizam Non BB...   in
# 5618  welkin moon giveaway bc finally money -u got t...   en
# 5619  Manam edi chesina Daaniki kuda elevation istad...   et
# 5620  This first time I 've seen Government media le...   en
#
# [5621 rows x 2 columns]

# %% [markdown]
# ### uni-variate Analysis on Hashtags

# %%
re.findall?

# %%
#Method to find hashtags from tweets
def find_hashtags(tweet):
    '''This function will extract hashtags'''
    return re.findall('(#[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

# %%
# update Hashtag column with hashtags extracted from Orignal_text columon
tweets_df['hashtags'] = tweets['original_text'].apply(lambda x: find_hashtags(x))
print(tweets_df['hashtags'])
# Out:
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3       [#Desertification, #Drought, #resilience, #bio...
# 4                         [#GregHunt, #Morrison, #auspol]
#                               ...
# 5616                                             [#QandA]
# 5617                                                   []
# 5618                                                   []
# 5619                                                   []
# 5620                                                   []
# Name: hashtags, Length: 5621, dtype: object

# %%
# take the rows from the hashtag columns where there are actually hashtags
hashtags_list_df = tweets_df.loc[
                       tweets_df.hashtags.apply(
                           lambda hashtags_list: hashtags_list !=[]
                       ),['hashtags']]

# %%
hashtags_list_df
# Out:
#                                                hashtags
# 3     [#Desertification, #Drought, #resilience, #bio...
# 4                       [#GregHunt, #Morrison, #auspol]
# 5     [#HowRutoSabotagedUhuru, #JKLive, #javascript,...
# 6     [#Desertification, #Drought, #resilience, #bio...
# 9                                         [#microgrids]
# ...                                                 ...
# 5611                                           [#QandA]
# 5613  [#npcindia, #webinar, #wastemgmt, #carboncredi...
# 5614      [#mobilemoney, #Burundi, #youth, #innovation]
# 5615                    [#CarbonSmart, #OurCleanFuture]
# 5616                                           [#QandA]
#
# [2022 rows x 1 columns]

# %%
 #create dataframe where each use of hashtag gets its own row
flattened_hashtags_df = pd.DataFrame(
    [hashtag for hashtags_list in hashtags_list_df.hashtags
    for hashtag in hashtags_list],
    columns=['hashtag'])

# %%
flattened_hashtags_df
# Out:
#                hashtag
# 0     #Desertification
# 1             #Drought
# 2          #resilience
# 3        #biodiversity
# 4       #climatechange
# ...                ...
# 4245            #youth
# 4246       #innovation
# 4247      #CarbonSmart
# 4248   #OurCleanFuture
# 4249            #QandA
#
# [4250 rows x 1 columns]

# %% [markdown]
# ### Analyzing data using language attribute

# %%
# To plot Top 20 Hashtags
plt.figure(figsize=(4, 4), dpi=200)
flattened_hashtags_df.value_counts()[:10].plot(kind='barh', title = "Top 10 hashtags")
plt.show()

# %%
tweets_by_lang = tweets['lang'].value_counts()
print(tweets_by_lang)
# Out:
# en      3408
# et      1152
# in       572
# tl       116
# es        68
# fi        50
# fr        46
# ht        42
# it        36
# hi        34
# und       32
# ja        28
# pl        16
# pt         6
# de         4
# tr         4
# nl         4
# no         2
# lang       1
# Name: lang, dtype: int64

# %%
fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Languages', fontsize=10)
ax.set_ylabel('Number of tweets' , fontsize=10)
ax.set_title('Top 5 languages', fontsize=10)
tweets_by_lang[:5].plot(ax=ax, kind='bar', color='orange')
# Out:
# <AxesSubplot:title={'center':'Top 5 languages'}, xlabel='Languages', ylabel='Number of tweets'>

# %%
#from Our Language analysis we can see there are differnt languages we can select only tweets with english 
English_tweets = tweets.loc[tweets['lang'] =="en"]

# %%
English_tweets
# Out:
#       Unnamed: 0                      created_at  \
# 0            0.0  Thu Jun 17 06:26:34 +0000 2021
# 3            3.0  Thu Jun 17 06:26:44 +0000 2021
# 4            4.0  Thu Jun 17 06:26:47 +0000 2021
# 5            5.0  Thu Jun 17 06:26:49 +0000 2021
# 6            6.0  Thu Jun 17 06:26:50 +0000 2021
# ...          ...                             ...
# 5613      2802.0  Thu Jun 17 10:20:57 +0000 2021
# 5615      2804.0  Thu Jun 17 10:20:59 +0000 2021
# 5616      2805.0  Thu Jun 17 10:21:02 +0000 2021
# 5618      2807.0  Thu Jun 17 10:21:08 +0000 2021
# 5620      2809.0  Thu Jun 17 10:21:10 +0000 2021
#
#                                                  source  \
# 0     <a href="https://mobile.twitter.com" rel="nofo...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/android" ...
# 5     <a href="https://mobile.twitter.com" rel="nofo...
# 6     <a href="https://help.twitter.com/en/using-twi...
# ...                                                 ...
# 5613  <a href="https://mobile.twitter.com" rel="nofo...
# 5615  <a href="https://mobile.twitter.com" rel="nofo...
# 5616  <a href="https://mobile.twitter.com" rel="nofo...
# 5618  <a href="http://twitter.com/download/android" ...
# 5620  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                           original_text  \
# 0     Giving forth life is becoming a burden in Keny...
# 3     Today is World Day to Combat #Desertification ...
# 4     Hearing #GregHunt say he's confident vaccines ...
# 5     Buy airtime across all networks from Mpesa eve...
# 6     Today is World Day to Combat #Desertification ...
# ...                                                 ...
# 5613  Join @NPC_INDIA_GOV webinar on "Carbon Credits...
# 5615  In the latest episode of @LanzaTech’s #CarbonS...
# 5616  Lambie has voted AGAINST Medivac, Carbon tax, ...
# 5618  welkin moon giveaway bc i finally have money!\...
# 5620  This is the first time I've seen the Governmen...
#
#                                              clean_text  \
# 0     Giving forth life becoming burden Kenya This m...
# 3     Today World Day Combat Restoring degraded land...
# 4     Hearing say 's confident vaccines delivered li...
# 5     Buy airtime across networks Mpesa even Fuliza ...
# 6     Today World Day Combat Restoring degraded land...
# ...                                                 ...
# 5613  Join webinar `` Carbon Credits Waste Managemen...
# 5615  In latest episode podcast Unilevers Peter Ter ...
# 5616  Lambie voted AGAINST Medivac Carbon tax protec...
# 5618  welkin moon giveaway bc finally money -u got t...
# 5620  This first time I 've seen Government media le...
#
#                                               sentiment             polarity  \
# 0     Sentiment(polarity=0.3194444444444445, subject...   0.3194444444444445
# 3           Sentiment(polarity=0.25, subjectivity=0.65)                 0.25
# 4     Sentiment(polarity=0.5, subjectivity=0.8333333...                  0.5
# 5             Sentiment(polarity=0.0, subjectivity=0.0)                  0.0
# 6           Sentiment(polarity=0.25, subjectivity=0.65)                 0.25
# ...                                                 ...                  ...
# 5613         Sentiment(polarity=-0.2, subjectivity=0.0)                 -0.2
# 5615  Sentiment(polarity=0.2791666666666667, subject...   0.2791666666666667
# 5616  Sentiment(polarity=0.13636363636363635, subjec...  0.13636363636363635
# 5618  Sentiment(polarity=0.15416666666666667, subjec...  0.15416666666666667
# 5620  Sentiment(polarity=0.13, subjectivity=0.406666...                 0.13
#
#              subjectivity lang favorite_count  ... original_author  \
# 0      0.5305555555555556   en              0  ...        reen_law
# 3                    0.65   en              0  ...     CIACOceania
# 4      0.8333333333333334   en              0  ...   MccarronWendy
# 5                     0.0   en              0  ...       OmarLali_
# 6                    0.65   en              0  ...   SustainTrends
# ...                   ...  ...            ...  ...             ...
# 5613                  0.0   en              0  ...     arunkjhaies
# 5615   0.5145833333333334   en              0  ...      ClimateCLG
# 5616  0.45454545454545453   en              0  ...    TrixAnabella
# 5618                  0.5   en              0  ...     acquitaine_
# 5620   0.4066666666666666   en              0  ...          NetNym
#
#      screen_count followers_count friends_count possibly_sensitive  \
# 0             398              70           223                NaN
# 3            7039             343           387                NaN
# 4           26064             419           878                NaN
# 5           12376            3134          3167                NaN
# 6          299346            5930           159                NaN
# ...           ...             ...           ...                ...
# 5613        59391            2527           965                NaN
# 5615        10887           11086          3000                NaN
# 5616        65144             644          1064                NaN
# 5618          520             365           581                NaN
# 5620         7783             207           874                NaN
#
#                                   hashtags                  user_mentions  \
# 0                                      NaN                  janetmachuka_
# 3     Desertification, Drought, resilience                    EdwardVrkic
# 4                       GregHunt, Morrison                  WriteWithDave
# 5                                      NaN        iamsoniah, F_M_Networks
# 6     Desertification, Drought, resilience                    EdwardVrkic
# ...                                    ...                            ...
# 5613                                   NaN   NPC_INDIA_GOV, NPC_INDIA_GOV
# 5615                           CarbonSmart  Unilever, LanzaTech, TodaDogs
# 5616                                   NaN                    davidbewart
# 5618                                   NaN                       siilveon
# 5620                                   NaN                 CharlotteCGill
#
#      place   place_coord_boundaries                  timestamp
# 0      NaN                      NaN  2021-06-17 06:26:34+00:00
# 3      NaN         Papua New Guinea  2021-06-17 06:26:44+00:00
# 4      NaN  Sydney, New South Wales  2021-06-17 06:26:47+00:00
# 5      NaN                    Kenya  2021-06-17 06:26:49+00:00
# 6      NaN                      NaN  2021-06-17 06:26:50+00:00
# ...    ...                      ...                        ...
# 5613   NaN                New Delhi  2021-06-17 10:20:57+00:00
# 5615   NaN          UK and Brussels  2021-06-17 10:20:59+00:00
# 5616   NaN                      NaN  2021-06-17 10:21:02+00:00
# 5618   NaN                deez nuts  2021-06-17 10:21:08+00:00
# 5620   NaN   Rogue State of England  2021-06-17 10:21:10+00:00
#
# [3408 rows x 21 columns]

# %% [markdown]
# ###Text Preprocessing

# %%
#text Preprocessing
English_tweets['clean_text']=English_tweets['clean_text'].astype(str)
English_tweets['clean_text'] = English_tweets['clean_text'].apply(lambda x: x.lower())
English_tweets['clean_text']= English_tweets['clean_text'].apply(lambda x: x.translate(str.maketrans(' ', ' ', string.punctuation)))

# %%
plt.figure(figsize=(20, 10))
plt.imshow(WordCloud(width=1000,height=600,stopwords=STOPWORDS).generate(' '.join(English_tweets.clean_text .values)))
plt.axis('off')
plt.title('Most Frequent Words In Our Tweets',fontsize=22)
plt.show()

# %% [markdown]
# # **Assignment 2 for Practice**

# %% [markdown]
# ## *Top 10 Mentioned Names*

# %%
plt.figure(figsize=(4, 4), dpi=200)
tweets.user_mentions.value_counts()[:10].plot(kind = "bar", color = "orange")
plt.title("Top 10 Most mentioned Names")
plt.show()

# %%
#plt.pie(, labels = )
t = tweets.possibly_sensitive.value_counts()
plt.figure(figsize=(4, 4), dpi=200)
plt.pie(t, autopct='%.0f%%', labels = t.index, explode=(0, 0.8, 1))
plt.title("Possibly sensitive", fontsize = 22)
plt.show()
